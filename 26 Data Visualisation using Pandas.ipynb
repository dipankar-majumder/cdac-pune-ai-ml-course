# %% [markdown]
# ##### Data Visualisation using Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/student.csv')
df.plot()
# Out:
# <Axes: >

# %%
df.plot(x='roll', y='marks')
# Out:
# <Axes: xlabel='roll'>

# %%
df.plot.bar(x='name', y='marks')
# Out:
# <Axes: xlabel='name'>

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df['marks'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['marks'].plot.pie(labels=df['name'], autopct='%2.2f%%')
# Out:
# <Axes: ylabel='marks'>

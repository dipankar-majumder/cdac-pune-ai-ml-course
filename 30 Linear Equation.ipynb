# %% [markdown]
# ##### Linear Equation

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1, 10, 0.25)
x
# Out:
# array([1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 ,
#        3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25,
#        6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  , 8.25, 8.5 , 8.75, 9.  ,
#        9.25, 9.5 , 9.75])

# %%
y = 0.67 * x + 12.485
y
# Out:
# array([13.155 , 13.3225, 13.49  , 13.6575, 13.825 , 13.9925, 14.16  ,
#        14.3275, 14.495 , 14.6625, 14.83  , 14.9975, 15.165 , 15.3325,
#        15.5   , 15.6675, 15.835 , 16.0025, 16.17  , 16.3375, 16.505 ,
#        16.6725, 16.84  , 17.0075, 17.175 , 17.3425, 17.51  , 17.6775,
#        17.845 , 18.0125, 18.18  , 18.3475, 18.515 , 18.6825, 18.85  ,
#        19.0175])

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)

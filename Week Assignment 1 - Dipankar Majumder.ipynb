# %% [markdown]
# #### Week Assignment 1

# %% [markdown]
# #### Problem Statements on pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 1. Download the file airquality.csv and perform the following

# %% [markdown]
# ##### 1. Read the file

# %%
df = pd.read_csv('datasets/airquality.csv')
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %% [markdown]
# ##### 2. Print number of rows and columns

# %%
print('(rows, columns) =', df.shape)
# Out:
# (rows, columns) = (153, 7)

# %% [markdown]
# ##### 3. Print the names of columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day'], dtype='object')

# %% [markdown]
# ##### 4. Extract the rows from 10 to 25 and print on screen

# %%
df[10:25 + 1]
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 10          11    7.0      NaN   6.9    74      5   11
# 11          12   16.0    256.0   9.7    69      5   12
# 12          13   11.0    290.0   9.2    66      5   13
# 13          14   14.0    274.0  10.9    68      5   14
# 14          15   18.0     65.0  13.2    58      5   15
# 15          16   14.0    334.0  11.5    64      5   16
# 16          17   34.0    307.0  12.0    66      5   17
# 17          18    6.0     78.0  18.4    57      5   18
# 18          19   30.0    322.0  11.5    68      5   19
# 19          20   11.0     44.0   9.7    62      5   20
# 20          21    1.0      8.0   9.7    59      5   21
# 21          22   11.0    320.0  16.6    73      5   22
# 22          23    4.0     25.0   9.7    61      5   23
# 23          24   32.0     92.0  12.0    61      5   24
# 24          25    NaN     66.0  16.6    57      5   25
# 25          26    NaN    266.0  14.9    58      5   26

# %% [markdown]
# ##### 5. Sort the data using temperature column

# %%
df.sort_values('Temp')
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 4             5    NaN      NaN  14.3    56      5    5
# 17           18    6.0     78.0  18.4    57      5   18
# 24           25    NaN     66.0  16.6    57      5   25
# 26           27    NaN      NaN   8.0    57      5   27
# 14           15   18.0     65.0  13.2    58      5   15
# ..          ...    ...      ...   ...   ...    ...  ...
# 41           42    NaN    259.0  10.9    93      6   11
# 122         123   85.0    188.0   6.3    94      8   31
# 120         121  118.0    225.0   2.3    94      8   29
# 121         122   84.0    237.0   6.3    96      8   30
# 119         120   76.0    203.0   9.7    97      8   28
#
# [153 rows x 7 columns]

# %% [markdown]
# ##### 6. Convert the temperature from farenheight to centigrade

# %%
df['Temp'] = (df['Temp'] - 32) * 5 / 9
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind       Temp  Month  Day
# 0             1   41.0    190.0   7.4  19.444444      5    1
# 1             2   36.0    118.0   8.0  22.222222      5    2
# 2             3   12.0    149.0  12.6  23.333333      5    3
# 3             4   18.0    313.0  11.5  16.666667      5    4
# 4             5    NaN      NaN  14.3  13.333333      5    5
# ..          ...    ...      ...   ...        ...    ...  ...
# 148         149   30.0    193.0   6.9  21.111111      9   26
# 149         150    NaN    145.0  13.2  25.000000      9   27
# 150         151   14.0    191.0  14.3  23.888889      9   28
# 151         152   18.0    131.0   8.0  24.444444      9   29
# 152         153   20.0    223.0  11.5  20.000000      9   30
#
# [153 rows x 7 columns]

# %% [markdown]
# ##### 7. Display the information of fifth month only

# %%
df[df['Month'] == 5]
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind       Temp  Month  Day
# 0            1   41.0    190.0   7.4  19.444444      5    1
# 1            2   36.0    118.0   8.0  22.222222      5    2
# 2            3   12.0    149.0  12.6  23.333333      5    3
# 3            4   18.0    313.0  11.5  16.666667      5    4
# 4            5    NaN      NaN  14.3  13.333333      5    5
# 5            6   28.0      NaN  14.9  18.888889      5    6
# 6            7   23.0    299.0   8.6  18.333333      5    7
# 7            8   19.0     99.0  13.8  15.000000      5    8
# 8            9    8.0     19.0  20.1  16.111111      5    9
# 9           10    NaN    194.0   8.6  20.555556      5   10
# 10          11    7.0      NaN   6.9  23.333333      5   11
# 11          12   16.0    256.0   9.7  20.555556      5   12
# 12          13   11.0    290.0   9.2  18.888889      5   13
# 13          14   14.0    274.0  10.9  20.000000      5   14
# 14          15   18.0     65.0  13.2  14.444444      5   15
# ...

# %% [markdown]
# #### 2. Use the given file named cricket.csv and perform the following operations:

# %% [markdown]
# ##### 1. Read the file in DataFrame

# %%
df = pd.read_csv('datasets/cricket.csv')
df
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings
# 0      1    Anil Dalpat      122  6755       56       12          0
# 1      2   Rohan Kanhay      144  1256       76      178          0
# 2      3  Avdhoot Dighe      265  8954      120        0          0
# 3      4       Bahubali       10   756        6       11          3
# 4      5      Leeladhar      234  2866      105      376          0
# 5      6      Pradyumna      177  5877       47      122          0
# 6      7     Dinesh Roy      211  8537      112       16          0
# 7      8     Parmeshwar      245  9466       53        0          0
# 8      9    Ali Durrani       55  2756       12       26          0
# 9     10   Litesh Singh       89  1099       46       49          0

# %% [markdown]
# ##### 2. List the name of cricketer and their respective runs

# %%
df[['name', 'runs']]
# Out:
#             name  runs
# 0    Anil Dalpat  6755
# 1   Rohan Kanhay  1256
# 2  Avdhoot Dighe  8954
# 3       Bahubali   756
# 4      Leeladhar  2866
# 5      Pradyumna  5877
# 6     Dinesh Roy  8537
# 7     Parmeshwar  9466
# 8    Ali Durrani  2756
# 9   Litesh Singh  1099

# %% [markdown]
# ##### 3. Find total wickets taken by them

# %%
df['wickets'].sum()
# Out:
# 790

# %% [markdown]
# ##### 4. Find average of catches taken

# %%
df['catches'].mean()
# Out:
# 63.3

# %% [markdown]
# ##### 5. Calculate strike rates of all the batsmen

# %%
# Assuming 100 balls faced per match (as balls faced is not given)
df['ball_faced'] = df['matches'] * 100

# Calculate strike rate and display results
df['strike_rate'] = ((df['runs'] / df['ball_faced']) * 100).round(2)
df
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings  \
# 0      1    Anil Dalpat      122  6755       56       12          0
# 1      2   Rohan Kanhay      144  1256       76      178          0
# 2      3  Avdhoot Dighe      265  8954      120        0          0
# 3      4       Bahubali       10   756        6       11          3
# 4      5      Leeladhar      234  2866      105      376          0
# 5      6      Pradyumna      177  5877       47      122          0
# 6      7     Dinesh Roy      211  8537      112       16          0
# 7      8     Parmeshwar      245  9466       53        0          0
# 8      9    Ali Durrani       55  2756       12       26          0
# 9     10   Litesh Singh       89  1099       46       49          0
#
#    ball_faced  strike_rate
# 0       12200        55.37
# 1       14400         8.72
# 2       26500        33.79
# 3        1000        75.60
# 4       23400        12.25
# 5       17700        33.20
# ...

# %% [markdown]
# ##### 6. Print the names of person who has strike rate greater than 50

# %%
df[df['strike_rate'] > 50]
# Out:
#    sr.no         name  matches  runs  catches  wickets  stumpings  ball_faced  \
# 0      1  Anil Dalpat      122  6755       56       12          0       12200
# 3      4     Bahubali       10   756        6       11          3        1000
# 8      9  Ali Durrani       55  2756       12       26          0        5500
#
#    strike_rate
# 0        55.37
# 3        75.60
# 8        50.11

# %% [markdown]
# ##### 7. Find the name of wicketkeeper

# %%
df[df['stumpings'] != 0]['name']
# Out:
# 3    Bahubali
# Name: name, dtype: object

# %% [markdown]
# ##### 8. Print the name of bowler who played highest number of matches

# %%
df[df['wickets'] != 0].sort_values('matches', ascending=False).loc[0, 'name']
# Out:
# 'Anil Dalpat'

# %% [markdown]
# ##### 9. Find average of all the bowlers

# %%
df[df['wickets'] != 0]['wickets'].mean()
# Out:
# 98.75

# %% [markdown]
# ##### 10. Find name of the bowler with least bowling average

# %%
df['bowling_average'] = df['runs'] / df['wickets']
df.sort_values('bowling_average')['name'].values[0]
# Out:
# 'Rohan Kanhay'

# %% [markdown]
# ##### 11. Print information about all players whose catches per match ratio is greater than 0.5 store it in a csv file

# %%
df['catches_per_match'] = df['catches'] / df['matches']
df[df['catches_per_match'] > 0.5].to_csv('datasets/output.csv', index=False)

# %% [markdown]
# ##### 12. Draw the chart of matches against number of runs scored

# %%
df.plot.scatter(x='matches', y='runs')
# Out:
# <Axes: xlabel='matches', ylabel='runs'>

# %% [markdown]
# ##### 13. Sort and print information about players by ascending order of runs

# %%
df.sort_values('runs', ascending=True)
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings  \
# 3      4       Bahubali       10   756        6       11          3
# 9     10   Litesh Singh       89  1099       46       49          0
# 1      2   Rohan Kanhay      144  1256       76      178          0
# 8      9    Ali Durrani       55  2756       12       26          0
# 4      5      Leeladhar      234  2866      105      376          0
# 5      6      Pradyumna      177  5877       47      122          0
# 0      1    Anil Dalpat      122  6755       56       12          0
# 6      7     Dinesh Roy      211  8537      112       16          0
# 2      3  Avdhoot Dighe      265  8954      120        0          0
# 7      8     Parmeshwar      245  9466       53        0          0
#
#    ball_faced  strike_rate  bowling_average  catches_per_match
# 3        1000        75.60        68.727273           0.600000
# 9        8900        12.35        22.428571           0.516854
# ...

# %% [markdown]
# ##### 14. Print the names of players whose wickets are greater than matches

# %%
df[df['wickets'] > df['matches']]
# Out:
#    sr.no          name  matches  runs  catches  wickets  stumpings  \
# 1      2  Rohan Kanhay      144  1256       76      178          0
# 3      4      Bahubali       10   756        6       11          3
# 4      5     Leeladhar      234  2866      105      376          0
#
#    ball_faced  strike_rate  bowling_average  catches_per_match
# 1       14400         8.72         7.056180           0.527778
# 3        1000        75.60        68.727273           0.600000
# 4       23400        12.25         7.622340           0.448718

# %% [markdown]
# ##### Feature Selection - Wrapper Methods

# %% [markdown]
# ##### Dataset

# %% [markdown]
# Download `mtcars.csv`
#
# Location: https://mitu.co.in/dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('datasets/mtcars.csv')

# %%
x = df[['disp', 'hp', 'wt']]
y = df['mpg']

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()
regressor.fit(x, y)
print('Accuracy:', regressor.score(x, y))
# Out:
# Accuracy: 0.8268361424946447

# %%
x = df.drop('mpg', axis=1)

# %% [markdown]
# ##### Recursive Feature Elimination

# %%
from sklearn.feature_selection import RFE

# %%
rfe = RFE(estimator=LinearRegression(), n_features_to_select=3)
rfe.fit(x, y)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=3)

# %%
x_new = x.loc[:, rfe.get_support()]
x_new
# Out:
#        wt   qsec  am
# 0   2.620  16.46   1
# 1   2.875  17.02   1
# 2   2.320  18.61   1
# 3   3.215  19.44   0
# 4   3.440  17.02   0
# 5   3.460  20.22   0
# 6   3.570  15.84   0
# 7   3.190  20.00   0
# 8   3.150  22.90   0
# 9   3.440  18.30   0
# 10  3.440  18.90   0
# 11  4.070  17.40   0
# 12  3.730  17.60   0
# 13  3.780  18.00   0
# 14  5.250  17.98   0
# 15  5.424  17.82   0
# 16  5.345  17.42   0
# 17  2.200  19.47   1
# 18  1.615  18.52   1
# 19  1.835  19.90   1
# 20  2.465  20.01   0
# 21  3.520  16.87   0
# 22  3.435  17.30   0
# 23  3.840  15.41   0
# 24  3.845  17.05   0
# 25  1.935  18.90   1
# 26  2.140  16.70   1
# 27  1.513  16.90   1
# 28  3.170  14.50   1
# 29  2.770  15.50   1
# 30  3.570  14.60   1
# 31  2.780  18.60   1

# %%
regressor = LinearRegression()
regressor.fit(x_new, y)
print('Accuracy:', regressor.score(x_new, y))
# Out:
# Accuracy: 0.8496635563617072

# %% [markdown]
# ##### Polynomial Function

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1, 10, 0.25)
x
# Out:
# array([1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 ,
#        3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25,
#        6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  , 8.25, 8.5 , 8.75, 9.  ,
#        9.25, 9.5 , 9.75])

# %%
y = x ** 4 * 5.22 + 16.37
y
# Out:
# array([2.15900000e+01, 2.91141406e+01, 4.27962500e+01, 6.53278906e+01,
#        9.98900000e+01, 1.50152891e+02, 2.20276250e+02, 3.14909141e+02,
#        4.39190000e+02, 5.98746641e+02, 7.99696250e+02, 1.04864539e+03,
#        1.35269000e+03, 1.71941539e+03, 2.15689625e+03, 2.67369664e+03,
#        3.27887000e+03, 3.98195914e+03, 4.79299625e+03, 5.72250289e+03,
#        6.78149000e+03, 7.98145789e+03, 9.33439625e+03, 1.08527841e+04,
#        1.25495900e+04, 1.44382716e+04, 1.65327762e+04, 1.88475404e+04,
#        2.13974900e+04, 2.41980404e+04, 2.72650962e+04, 3.06150516e+04,
#        3.42647900e+04, 3.82316841e+04, 4.25335963e+04, 4.71888779e+04])

# %%
plt.plot(x, y)
